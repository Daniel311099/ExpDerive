# %%
from ExpDerive.nlp.compiler.preprocesser import preprocess
from ExpDerive.nlp.compiler.utils import insertArgDelimiters, insertFuncDelimiters, parseArgs, parseFunc
from saytex import Saytex
# import parse latex
from sympy.parsing.latex import parse_latex

# %%
# comp = Saytex()
# lat = comp.to_latex("square root of goals")
# print(lat)
parse_latex("\sqrt {\mathit{goals}}")
# Out:
# sqrt(goals)

# %%
new_funcs = [
    "average",
    "sum",
    "myFunc1",
    "myFunc2",
]

# %% [markdown]
# name1: ada:ft-personal-2022-10-17-20-19-20
# name2: davinci:ft-personal-2022-10-18-17-53-30
# name3: davinci:ft-personal-2022-10-19-02-08-02
# name4: ada:ft-personal-2022-10-19-11-12-40
#
# from "where openai":
#
# run: openai tools fine_tunes.prepare_data -f /Users/danielfisaha/FB_REF_TOOLS/FB-REF-TOOLS/code/back-end/fb_ref_project/tests/training.jsonl
#
# run: python openai -k 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 api fine_tunes.create -t /Users/danielfisaha/FB_REF_TOOLS/FB-REF-TOOLS/code/back-end/fb_ref_project/tests/training_prepared.jsonl -m davinci

# %%
phrase = "goals scored"
def get_embedding(phrase):
    return openai.Embedding.create(
        input=phrase,
        model="text-embedding-ada-002",
    )['data'][0]['embedding']

# %%
embeddings = [
    (phrase, get_embedding(phrase))
    for phrase in new_funcs
]
print(embeddings)
# Out:
# [[-0.013725780881941319, -0.0012294299667701125, 0.024862566962838173, -0.022972188889980316, -0.024766677990555763, -0.009184766560792923, -0.016958599910140038, -0.023287253454327583, -0.014520286582410336, -0.03715001791715622, 0.019533894956111908, 0.026807736605405807, -0.002292766934260726, 0.0024708460550755262, 0.0016480868216603994, 0.022095493972301483, 0.045779999345541, -0.0012653882149606943, 0.0128764808177948, -0.005150592420250177, -0.006808096542954445, 0.019739370793104172, -0.022972188889980316, -0.011212127283215523, -0.019205134361982346, -0.002840702421963215, 0.012369640171527863, -0.02031470276415348, 0.01237649004906416, -0.00872587040066719, 0.022766713052988052, -0.008054649457335472, -0.025095438584685326, -0.0062601612880826, -0.010034066624939442, -0.014616175554692745, 0.0010624808492138982, -0.007013572379946709, 0.009924478828907013, -0.009451884776353836, 0.01683531329035759, -0.016314774751663208, 0.022109191864728928, -0.010095709003508091, -0.0131
# ...

# %%
import pinecone
api_key = "5837c25c-f54b-4dfc-9e4a-f00b694c0f67"
pinecone.init(api_key=api_key, environment="us-west4-gcp")
index_name = "name"
index = pinecone.Index(index_name)
index

# %%
res = index.query(
    vector=embbeding["embedding"],
    top_k=10,
    include_metadata=True,
    namespace="variables"
).matches[0]

# %%
res
# Out:
# {'id': 'goals',
#  'metadata': {'dataType': 'float',
#               'description': 'goals scored',
#               'label': 'goals',
#               'type': 'standard'},
#  'score': 1.00523674,
#  'values': []}

# %%
import openai
api_key = "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"
openai.api_key = api_key
engine = "davinci:ft-personal-2022-10-19-02-08-02"
def f(p):
    response = openai.Completion.create(
        engine=engine,
        prompt = p,
    )
    return response
